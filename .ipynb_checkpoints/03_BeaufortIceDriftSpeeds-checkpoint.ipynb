# %%
# general
import numpy as np, numpy.ma as ma
import xarray as xr
import pandas as pd

# time
# import datetime as dt
from datetime import datetime, timedelta
import calendar

# local system 
import sys  
import glob
import os

# plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
import matplotlib.colors
import matplotlib.patches as mpatches
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.colors import Normalize
from matplotlib.lines import Line2D

# geo plotting
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeat


import cmocean

import shapely
import warnings
from shapely.errors import ShapelyDeprecationWarning
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning) 


sys.path.append('../Libraries_functions/')
from LIB_ASI_SIC_UniB import grab_ASI_SIC
from LIB_PPdrift_NSIDC0116 import grab_ice_Drift, grab_icedrift_range


sys.path.append('../')
import data_UniBremen.SIC as UNISIC

# %% [markdown]
# ## Grab SIC coordinates

# %%
coords = {}

try:
    coords['SIC'] = UNISIC.open_local_file(date=datetime(2008, 3, 1, 0, 0))

except:
    []

# %% [markdown]
# ## Grab sea ice motion coordinates

# %%
(u, xx_d, yy_d, lon, lat, drift_proj) = grab_ice_Drift(date=datetime(2000,1,1), return_vars=['u','xx', 'yy', 'lon', 'lat', 'proj'], 
                                          lat_range=[0, 90], lon_range=[0, 360])

coords['sim'] = {}

coords['sim']['xx'] = xx_d
coords['sim']['yy'] = yy_d
coords['sim']['proj'] = drift_proj
coords['sim']['lat'] = lat
coords['sim']['lon'] = lon
coords['sim']['mask'] = np.isnan(u)

# %% [markdown]
# ## Grab ERA5 reanalysis coordinates

# %%
ds = xr.open_dataset('/Volumes/Jewell_EasyStore/ECMWF/annual/daily/ERA5_1979_daily.nc')
ds.close()
longrid, latgrid = np.meshgrid(ds.longitude, ds.latitude)


coords['era'] = {}
coords['era']['xx'] = longrid
coords['era']['yy'] = latgrid
coords['era']['proj'] = ccrs.PlateCarree()
coords['era']['lat'] = latgrid
coords['era']['lon'] = longrid

# %% [markdown]
# ### Import MASIE regions

# %%
ds = xr.open_dataset('/Volumes/Seagate_Jewell/KenzieStuff/MASIE/masiemask_ims4km.nc')
ds.close()

CRS = ds.polar_stereographic.attrs
MASIE_proj = ccrs.Stereographic(central_latitude=CRS['latitude_of_projection_origin'], 
                                central_longitude=CRS['straight_vertical_longitude_from_pole'], 
                             false_easting=CRS['false_easting'],
                             false_northing=CRS['false_northing'],
                             true_scale_latitude=CRS['standard_parallel'])

# save to dictionary
coords['MASIE'] = {}
coords['MASIE']['xx'] = ds.x.values
coords['MASIE']['yy'] = ds.y.values
coords['MASIE']['proj'] = MASIE_proj
coords['MASIE']['lat'] = ds.lat.values
coords['MASIE']['lon'] = ds.lon.values
coords['MASIE']['area'] = ds.area.values

# don't need to define globe since WGS84 ellipsoid is the cartopy default
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (x: 6144, y: 6144)
# Coordinates:
#   * x                    (x) float64 -1.229e+07 -1.228e+07 ... 1.229e+07
#   * y                    (y) float64 1.229e+07 1.228e+07 ... -1.229e+07
# Data variables:
#     mask                 (y, x) float32 ...
#     polar_stereographic  int32 ...
#     regions              (y, x) int8 ...
#     lat                  (y, x) float32 -21.48 -21.48 -21.47 ... -21.48 -21.48
#     lon                  (y, x) float32 145.0 145.0 145.0 ... -35.01 -35.0
#     area                 (y, x) float32 1.869 1.869 1.87 ... 1.87 1.869 1.869
# Attributes:
#     Conventions:    CF-1.4
#     institution:    National Snow and Ice Data Center, Boulder, CO
#     contact:        For assistance with this data, please contact the NSIDC U...
#     creation_time:  Wed Sep 23 07:12:35 2015
#     created_by:     vagrant

# %%
file = '/Volumes/Seagate_Jewell/KenzieStuff/MASIE/MASIE_regions_polygon_vertices.xlsx'

df = pd.read_excel(file, header=1, index_col=0)

rgn_bnds = {}
for rr in df.index.values:
    
    rgn_bnds[rr] = {}
    rgn_bnds[rr]['name'] = df.loc[rr][0]

    # grab coordinates
    coordinates = df.loc[rr][1:].values.astype(float)
    lats = coordinates[np.arange(0, len(coordinates), 2)]
    lons = coordinates[np.arange(1, len(coordinates), 2)]

    # remove nans
    rgn_bnds[rr]['lat'] = lats[np.isfinite(lats)]
    rgn_bnds[rr]['lon'] = lons[np.isfinite(lons)]
    
    
    out = coords['MASIE']['proj'].transform_points(ccrs.PlateCarree(), rgn_bnds[rr]['lon'], rgn_bnds[rr]['lat'])
    rgn_bnds[rr]['xx'] = out[:,0]
    rgn_bnds[rr]['yy'] = out[:,1]
    
    # repeat last point
    for coord in ['xx', 'yy', 'lat', 'lon']:
        rgn_bnds[rr][coord] = np.append(rgn_bnds[rr][coord], rgn_bnds[rr][coord][0])
# Out:
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_78804/3169947128.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rgn_bnds[rr]['name'] = df.loc[rr][0]
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_78804/3169947128.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   rgn_bnds[rr]['name'] = df.loc[rr][0]
# ...

# %% [markdown]
# ### Convert MASIE corner coordinates to SIC projection
#
# ### Find SIC points within Beaufort Sea

# %%
from shapely.geometry import Polygon, Point


out = coords['SIC']['proj'].transform_points(coords['MASIE']['proj'], rgn_bnds[1]['xx'], rgn_bnds[1]['yy'])
BF_xx = out[:,0]
BF_yy = out[:,1]

coordinates = list(zip(BF_xx, BF_yy))
poly_sic = Polygon(coordinates)

within_poly_sic = np.full(coords['SIC']['xx'].shape, False)

for ii in range(np.shape(within_poly_sic)[0]):
    for jj in range(np.shape(within_poly_sic)[1]):
        if poly_sic.contains(Point(coords['SIC']['xx'][ii, jj], coords['SIC']['yy'][ii, jj])):
            within_poly_sic[ii, jj] = True

# %% [markdown]
# ### Convert MASIE corner coordinates to SIM projection
#
# ### Find SIM points within Beaufort Sea

# %%
from shapely.geometry import Polygon, Point


out = coords['sim']['proj'].transform_points(coords['MASIE']['proj'], rgn_bnds[1]['xx'], rgn_bnds[1]['yy'])
BF_xx = out[:,0]
BF_yy = out[:,1]

coordinates = list(zip(BF_xx, BF_yy))
poly = Polygon(coordinates)

within_poly = np.full(coords['sim']['xx'].shape, False)

for ii in range(np.shape(within_poly)[0]):
    for jj in range(np.shape(within_poly)[1]):
        if poly.contains(Point(coords['sim']['xx'][ii, jj], coords['sim']['yy'][ii, jj])):
            within_poly[ii, jj] = True

# %% [markdown]
# ### Find ERA5 points within Beaufort Sea

# %%
from shapely.geometry import Polygon, Point

coordinates = list(zip(rgn_bnds[1]['lon'], rgn_bnds[1]['lat']))
geopoly = Polygon(coordinates)

within_poly_era = np.full(coords['era']['xx'].shape, False)

for ii in range(np.shape(within_poly_era)[0]):
    for jj in range(np.shape(within_poly_era)[1]):
        if geopoly.contains(Point(coords['era']['xx'][ii, jj], coords['era']['yy'][ii, jj])):
            if coords['era']['yy'][ii, jj] > 70:
                within_poly_era[ii, jj] = True

# %%
# %matplotlib inline


fig, ax = plt.subplots(figsize=(6,6), subplot_kw = {'projection': coords['sim']['proj']})
ax.set_ylim(-5000000,5000000)
ax.set_xlim(-5000000,5000000)


sp = 5
ax.pcolormesh(ds.x[::sp], ds.y[::sp], ds.regions[::sp,::sp], cmap='Set3', zorder=1, transform = coords['MASIE']['proj'])
ax.pcolormesh(ds.x[::sp], ds.y[::sp], ds.mask[::sp,::sp]==2, cmap=matplotlib.colors.ListedColormap(['None', 'darkgray']),transform = coords['MASIE']['proj'], zorder=2)
ax.pcolormesh(ds.x[::sp], ds.y[::sp], ds.mask[::sp,::sp]==5, cmap=matplotlib.colors.ListedColormap(['None', 'gray']),transform = coords['MASIE']['proj'], zorder=3)

for rr in rgn_bnds.keys():
    ax.plot(rgn_bnds[rr]['xx'], rgn_bnds[rr]['yy'], c='k', marker='o', lw=1, transform=coords['MASIE']['proj'], zorder=5)

ax.scatter(coords['sim']['xx'][coords['sim']['mask']==False], 
           coords['sim']['yy'][coords['sim']['mask']==False], 
           transform = coords['sim']['proj'], c='dodgerblue', s=1, zorder=4)

ax.scatter(0,90, c='r', s=50, transform=ccrs.PlateCarree(), zorder=100)


ax.scatter(BF_xx, BF_yy, marker='*',c='r', transform=coords['sim']['proj'], zorder=1000)
ax.add_geometries([poly], alpha=0.25, crs = coords['sim']['proj'], zorder=999)


ax.scatter(coords['sim']['xx'][within_poly], 
           coords['sim']['yy'][within_poly], 
           transform = coords['sim']['proj'], c='magenta', s=1, zorder=4)



ax.scatter(coords['era']['xx'][within_poly_era], 
           coords['era']['yy'][within_poly_era], 
           transform = coords['era']['proj'], c='gold', s=1, zorder=4)

# %% [markdown]
# ### Loop thru SIC data

# %%
# open cell areas
ds = xr.open_dataset('/Volumes/Seagate_Jewell/KenzieStuff/UniB-ASI-SIC-n6250/PolStereo_GridCellArea_n6.25km_Arctic.nc')
ds.close()
cellarea = ds.data.values


all_meansic = np.array([])
all_openextent = np.array([])

years = np.append(np.arange(2003, 2012), np.arange(2013, 2025))

# save daily vals
avg_sic = np.array([])
total_extent = np.array([])
    
    
for year in years:
    
    dates = pd.date_range(datetime(year, 1, 1), datetime(year, 1, 1) + timedelta(days=119))

    for date in dates:
    
        try:
            sic = grab_ASI_SIC(date=date, 
                             main_path='/Volumes/Seagate_Jewell/KenzieStuff/UniB-ASI-SIC-n6250/', 
                             coord_file='LongitudeLatitudeGrid-n6250-Arctic.hdf', 
                             hemisphere='n', resolution='6250', version='v5.4', 
                             return_vars=['sic'],  include_units=False, 
                               annual_folders=True, return_dict=False, quiet=True)
            
            mean_sic = np.nanmean(sic[within_poly_sic])
            
            open_ice = sic[within_poly_sic]<20
            areas = cellarea[within_poly_sic]
            open_extent = np.nansum(areas[open_ice]) # sq .km


        except:
            mean_sic = np.nan
            open_extent = np.nan

            
        avg_sic = np.append(avg_sic, mean_sic)
        total_extent = np.append(total_extent, open_extent)
        
    
avg_sic = np.reshape(avg_sic, (len(years), int(len(avg_sic)/len(years))))
total_extent = np.reshape(total_extent, (len(years), int(len(total_extent)/len(years))))
# Out:
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_78804/1118555945.py:31: RuntimeWarning: Mean of empty slice
#   mean_sic = np.nanmean(sic[within_poly_sic])

# %%
doy = np.arange(1,121)
doygrid, yeargrid = np.meshgrid(doy, years)

# %%
# fig, ax = plt.subplots(figsize=(8,3))
# ax.pcolormesh(doygrid, yeargrid, avg_sic, vmin=80, vmax=100, cmap=cmocean.cm.ice)
# ax.set_yticks(years);


fig, ax = plt.subplots(figsize=(8,3))
ax.pcolormesh(doygrid, yeargrid, total_extent, vmin=0, vmax=20000, cmap=cmocean.cm.ice_r)
ax.set_yticks(years);

# %%
total_extent.shape
# Out:
# (21, 120)

# %%
dates = pd.date_range(datetime(year, 1, 1), datetime(year, 1, 1) + timedelta(days=119))
years = np.append(np.arange(2003, 2012), np.arange(2013, 2025))

monthly_dates_sic = np.array([])
monthly_extents = np.array([])
monthly_sics = np.array([])

for yy, year in enumerate(years):
    
    for month in [1,2,3,4]:
    
        monthly_dates_sic = np.append(monthly_dates_sic, datetime(year, month, 1))
        monthly_extents = np.append(monthly_extents, np.nanmean(total_extent[yy, :][dates.month == month]))
        monthly_sics = np.append(monthly_sics, np.nanmean(avg_sic[yy, :][dates.month == month]))
    
    
date_months = np.array([date.month for date in monthly_dates_sic])
colors2 = []

for month in date_months:
    if month == 1:
        colors2.append('lightskyblue')
    elif month == 2:
        colors2.append('dodgerblue')
    elif month == 3:
        colors2.append('mediumpurple')
    else:
        colors2.append('lightcoral')

# %%
fig, ax = plt.subplots(figsize=(8,3))
ax.plot(monthly_dates_sic, monthly_sics, c='lightgray', zorder=0)
ax.scatter(monthly_dates_sic, monthly_sics, c=colors2, s=10, edgecolor='k', zorder=1)

# %% [markdown]
# ### Loop through all years

# %%
import metpy
from metpy.calc import wind_direction
from metpy.units import units


all_u = np.array([])
all_v = np.array([])
all_s = np.array([])
all_m = np.array([])
all_vort = np.array([])
all_shear = np.array([])
all_stretch = np.array([])

years = np.arange(2000, 2023)

# create weights for latitude-weighted mean
weights = np.cos(coords['era']['yy'][within_poly_era] * np.pi/180)

for year in years:
    
    print(year)
    ds = xr.open_dataset(f'/Volumes/Jewell_EasyStore/ECMWF/annual/daily/ERA5_{year}_daily.nc')
    ds.close()
    s10 = np.sqrt(ds.u10**2 + ds.v10**2)
    vort = metpy.calc.vorticity(ds.u10*units('m/s'), ds.v10*units('m/s'))
    shear = metpy.calc.shearing_deformation(ds.u10*units('m/s'), ds.v10*units('m/s'))
    stretch = metpy.calc.stretching_deformation(ds.u10*units('m/s'), ds.v10*units('m/s'))
    
    # find daily means
    avg_u = np.array([])
    avg_v = np.array([])
    avg_s = np.array([])
    avg_m = np.array([])
    avg_vort = np.array([])
    avg_shear = np.array([])
    avg_stretch = np.array([])
    
    for tt in range(len(ds.u10)): 
        
        u10_mean = np.sum(weights * ds.u10.values[tt][within_poly_era]) / np.sum(weights)
        v10_mean = np.sum(weights * ds.v10.values[tt][within_poly_era]) / np.sum(weights)
        s10_mean = np.sum(weights * s10.values[tt][within_poly_era]) / np.sum(weights)
        msl_mean = np.sum(weights * ds.msl.values[tt][within_poly_era]) / np.sum(weights)
        vort_mean = np.sum(weights * vort.values[tt][within_poly_era]) / np.sum(weights)
        shear_mean = np.sum(weights * shear.values[tt][within_poly_era]) / np.sum(weights)
        stretch_mean = np.sum(weights * stretch.values[tt][within_poly_era]) / np.sum(weights)
    
        avg_u = np.append(avg_u, u10_mean)
        avg_v = np.append(avg_v, v10_mean)
        avg_s = np.append(avg_s, s10_mean)
        avg_m = np.append(avg_m, msl_mean/100)
        avg_vort = np.append(avg_vort, vort_mean)
        avg_shear = np.append(avg_shear, shear_mean)
        avg_stretch = np.append(avg_stretch, stretch_mean)
        

    # save to master list
    all_u = np.append(all_u, avg_u[:365])
    all_v = np.append(all_v, avg_v[:365])
    all_s = np.append(all_s, avg_s[:365])
    all_m = np.append(all_m, avg_m[:365])
    all_vort = np.append(all_vort, avg_vort[:365])
    all_shear = np.append(all_shear, avg_shear[:365])
    all_stretch = np.append(all_stretch, avg_stretch[:365])
    
    
all_u = np.reshape(all_u, (len(years), int(len(all_u)/len(years))))
all_v = np.reshape(all_v, (len(years), int(len(all_v)/len(years))))
all_s = np.reshape(all_s, (len(years), int(len(all_s)/len(years))))
all_m = np.reshape(all_m, (len(years), int(len(all_m)/len(years))))
all_vort = np.reshape(all_vort, (len(years), int(len(all_vort)/len(years))))
all_shear = np.reshape(all_shear, (len(years), int(len(all_shear)/len(years))))
all_stretch = np.reshape(all_stretch, (len(years), int(len(all_stretch)/len(years))))
# Out:
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
year = 2022
dates = pd.date_range(datetime(year, 1, 1), datetime(year, 12, 31))


years = np.arange(2000, 2023)

# %%
monthly_dates = np.array([])
monthly_vorts = np.array([])
monthly_shear = np.array([])
monthly_stretch = np.array([])
monthly_vs = np.array([])
monthly_us = np.array([])
monthly_SE = np.array([])

SE_u = np.cos(135 * np.pi/180)
SE_v = np.sin(135 * np.pi/180)

for yy, year in enumerate(years):
    
    for month in [1,2,3,4]:
    
        monthly_dates = np.append(monthly_dates, datetime(year, month, 1))
        monthly_vorts = np.append(monthly_vorts, np.nanmean(all_vort[yy, :][dates.month == month]))
        monthly_shear = np.append(monthly_shear, np.nanmean(all_shear[yy, :][dates.month == month]))
        monthly_stretch = np.append(monthly_stretch, np.nanmean(all_stretch[yy, :][dates.month == month]))
        monthly_vs = np.append(monthly_vs, np.nanmean(all_v[yy, :][dates.month == month]))
        monthly_us = np.append(monthly_us, np.nanmean(all_u[yy, :][dates.month == month]))
        
        SE = all_u[yy, :][dates.month == month] * SE_u + all_v[yy, :][dates.month == month] * SE_v
        monthly_SE = np.append(monthly_SE, np.nanmean(SE))

    
date_years = np.array([date.year for date in monthly_dates])
date_months = np.array([date.month for date in monthly_dates])


monthly_dates = monthly_dates[date_years>1999]
monthly_vorts = monthly_vorts[date_years>1999]
monthly_shear = monthly_shear[date_years>1999]
monthly_stretch = monthly_stretch[date_years>1999]
monthly_us = monthly_us[date_years>1999]
monthly_vs = monthly_vs[date_years>1999]
monthly_SE = monthly_SE[date_years>1999]


date_months = date_months[date_years>1999]
date_years = date_years[date_years>1999]

# %%
plt.scatter(monthly_vorts, monthly_shear)

# %%
colors = []

for month in date_months:
    if month == 1:
        colors.append('lightskyblue')
    elif month == 2:
        colors.append('dodgerblue')
    elif month == 3:
        colors.append('mediumpurple')
    else:
        colors.append('lightcoral')

# %%
date_ticks = [datetime(year, 1, 1) for year in np.arange(2000,2023)]
date_labels = [date.strftime('%Y') for date in date_ticks]
for ii in np.arange(1, 21, 4):
    date_labels[ii] = ''
    date_labels[ii+1] = ''
    date_labels[ii+2] = ''
date_labels[21] = ''
date_labels[22] = ''



fig, axs = plt.subplots(4,1, figsize=(6,8))

for ax in axs:
    ax.set_xlim(datetime(1999,6,1), datetime(2022,10,1))

ax = axs[0]
ax.set_ylim(-0.000015,0.000015)
ax.set_ylabel('Wind vorticity ($s^{-1}$)')
# for year in date_years: 
#     ax.plot(monthly_dates[date_years==year], monthly_vorts[date_years==year], c='lightgray', zorder=0)
ax.scatter(monthly_dates, monthly_vorts, c=colors, edgecolor='k', zorder=1)
ax.axhline(0, c='k', zorder=-1)
ax.set_xticks(date_ticks)
ax.set_xticklabels(date_labels)

ax.scatter(0.45,1.08,c='lightskyblue', edgecolor='k',clip_on=False, transform=ax.transAxes)
ax.text(0.45,1.05, '  Jan',ha='left', va='bottom',clip_on=False, transform=ax.transAxes)
ax.scatter(0.6,1.08,c='dodgerblue', edgecolor='k',clip_on=False, transform=ax.transAxes)
ax.text(0.6,1.05, '  Feb',ha='left', va='bottom',clip_on=False, transform=ax.transAxes)
ax.scatter(0.75,1.08,c='mediumpurple', edgecolor='k',clip_on=False, transform=ax.transAxes)
ax.text(0.75,1.05, '  Mar',ha='left', va='bottom',clip_on=False, transform=ax.transAxes)
ax.scatter(0.9,1.08,c='lightcoral', edgecolor='k',clip_on=False, transform=ax.transAxes)
ax.text(0.9,1.05, '  Apr',ha='left', va='bottom',clip_on=False, transform=ax.transAxes)

ax = axs[1]
ax.set_ylabel('East wind ($m\;s^{-1}$)')
ax.set_ylim(-5,5)
# for year in date_years: 
#     ax.plot(monthly_dates[date_years==year], monthly_us[date_years==year], c='lightgray', zorder=0)
ax.scatter(monthly_dates, monthly_us, c=colors, edgecolor='k', zorder=1)
ax.axhline(0, c='k', zorder=-1)
ax.text(0.025,0.925, 'blow toward (+)', c='gray', transform=ax.transAxes)
ax.set_xticks(date_ticks)
ax.set_xticklabels(date_labels)

ax = axs[2]
ax.set_ylabel('North wind ($m\;s^{-1}$)')
ax.set_ylim(-5,5)
# for year in date_years: 
#     ax.plot(monthly_dates[date_years==year], monthly_vs[date_years==year], c='lightgray', zorder=0)
ax.scatter(monthly_dates, monthly_vs, c=colors, edgecolor='k', zorder=1)
ax.axhline(0, c='k', zorder=-1)
ax.text(0.025,0.925, 'blow toward (+)', c='gray', transform=ax.transAxes)
ax.set_xticks(date_ticks)
ax.set_xticklabels(date_labels)


ax = axs[3]
ax.set_ylabel('Mean SIC')
ax.set_ylim(94.5,100)
# for year in date_years: 
#     ax.plot(monthly_dates[date_years==year], monthly_vorts[date_years==year], c='lightgray', zorder=0)
ax.scatter(monthly_dates_sic, monthly_sics, c=colors2, edgecolor='k', zorder=1)
ax.set_xticks(date_ticks)
ax.set_xticklabels(date_labels)

ax.set_xlabel('Year, with JFMA monthly means')


from mpl_toolkits.axes_grid1.inset_locator import inset_axes
inset_ax = inset_axes(axs[0], width="100%", height="180%", loc='lower left',
                   bbox_to_anchor=(0.9, 1.3, 0.5, 0.5),
                   bbox_transform=ax.transAxes,
                   axes_class=cartopy.mpl.geoaxes.GeoAxes,
                   axes_kwargs=dict(map_projection=coords['sim']['proj']))

size = 3000000
inset_ax.set_ylim(-size,size)
inset_ax.set_xlim(-size,size)

sp = 5
inset_ax.pcolormesh(ds.x[::sp], ds.y[::sp], ds.mask[::sp,::sp]==2, cmap=matplotlib.colors.ListedColormap(['None', 'darkgray']),transform = coords['MASIE']['proj'], zorder=2)
# ax.pcolormesh(ds.x[::sp], ds.y[::sp], ds.mask[::sp,::sp]==5, cmap=matplotlib.colors.ListedColormap(['None', 'gray']),transform = coords['MASIE']['proj'], zorder=3)
for rr in rgn_bnds.keys():
    inset_ax.plot(rgn_bnds[rr]['xx'], rgn_bnds[rr]['yy'], c='k', marker='.', lw=1, transform=coords['MASIE']['proj'], zorder=5)
inset_ax.scatter(coords['era']['xx'][within_poly_era], 
           coords['era']['yy'][within_poly_era], 
           transform = coords['era']['proj'], c='gold', s=1, zorder=4)

# fig.savefig('/Users/mackenziejewell/Desktop/BeaufortSea_windforcing.png', dpi=300, pad_inches=0, bbox_inches='tight')
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\;'
# <>:48: SyntaxWarning: invalid escape sequence '\;'
# <>:37: SyntaxWarning: invalid escape sequence '\;'
# <>:48: SyntaxWarning: invalid escape sequence '\;'
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_86225/1869059186.py:37: SyntaxWarning: invalid escape sequence '\;'
#   ax.set_ylabel('East wind ($m\;s^{-1}$)')
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_86225/1869059186.py:48: SyntaxWarning: invalid escape sequence '\;'
#   ax.set_ylabel('North wind ($m\;s^{-1}$)')
# /opt/anaconda3/envs/BeaufortShelfBreakout/lib/python3.12/site-packages/cartopy/mpl/geoaxes.py:395: UserWarning: The `map_projection` keyword argument is deprecated, use `projection` to instantiate a GeoAxes instead.
#   warnings.warn("The `map_projection` keyword argument is "
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_86225/1869059186.py:37: SyntaxWarning: invalid escape sequence '\;'
# ...

# %%
directions = metpy.calc.wind_direction(monthly_us*units('cm/s'), 
                                       monthly_vs*units('cm/s'), 
                                       convention='to')

monthly_vs
# Out:
# array([-0.96226252, -1.31440522, -2.65998799, -1.54406912, -1.93638148,
#        -0.16885068, -1.92208985, -0.71984819, -0.51753765, -1.1237637 ,
#        -1.08333804,  0.47468724,  0.72465987, -1.51872929, -0.93606583,
#         0.71877271, -2.15493762, -2.50787572, -1.78192844, -1.13354482,
#        -0.65872352, -1.54651062, -1.72836984, -0.16323986, -0.68025917,
#         0.86355344, -0.28945901, -1.91541441, -0.9388819 , -0.19317237,
#        -0.17264031, -0.42126706, -0.38004091, -0.5292158 , -2.52014131,
#         0.56993506,  0.11978199,  0.52580273, -2.16974607,  1.1977801 ,
#         0.55280637, -2.55877189, -0.98415525, -0.36851395,  0.03271199,
#        -0.32678499,  1.19627303, -1.78654465, -1.41126201, -0.9083411 ,
#        -2.38290075, -0.66130151, -4.44233182, -1.44547554, -1.89473808,
#        -2.50090906, -1.08480386, -0.82011567, -0.06607583,  1.07720169,
#        -0.78834214,  0.12240902, -0.33998784, -0.44310313, -1.14284081,
# ...

# %%
matchings_sics = np.array([])

for date in monthly_dates:
    
    if date not in monthly_dates_sic:
        matchings_sics = np.append(matchings_sics, np.nan)
        
    else:
        
        matchings_sics = np.append(matchings_sics, monthly_sics[np.where(monthly_dates_sic == date)])

# %%
len(matchings_sics)
# Out:
# 92

# %%
monthly_sics
# Out:
# array([98.58167513, 99.45466877, 99.15798532, 98.03393555, 99.32984088,
#        99.71649065, 99.53641732, 99.12740642, 99.01058345, 99.5069217 ,
#        99.26258063, 99.00712059, 99.6180698 , 98.33984112, 98.89641842,
#        99.30702709, 99.54811465, 99.26937366, 99.52599212, 97.66948095,
#        99.44354051, 99.2060097 , 99.68665486, 98.20053732, 98.86377199,
#        98.69417335, 98.94546263, 98.86372665, 99.23817788, 99.33233584,
#        98.85261413, 98.25512459, 99.2913459 , 99.06762748, 99.15186851,
#        98.8762207 , 98.59967213, 99.36434989, 98.56988944, 98.60872203,
#        98.78005243, 98.63766637, 98.9697716 , 98.15730207, 99.100819  ,
#        98.29504131, 98.41511265, 97.82482963, 98.87926065, 98.8999155 ,
#        99.09505192, 95.11508968, 97.72706653, 98.70903331, 98.43924393,
#        98.47249998, 98.49646685, 98.4190637 , 98.25810882, 98.04884523,
#        98.95371271, 97.47957138, 96.77479602, 96.95186175, 98.80856053,
# ...

# %%
monthly_sics
# Out:
# array([98.58167513, 99.45466877, 99.15798532, 98.03393555, 99.32984088,
#        99.71649065, 99.53641732, 99.12740642, 99.01058345, 99.5069217 ,
#        99.26258063, 99.00712059, 99.6180698 , 98.33984112, 98.89641842,
#        99.30702709, 99.54811465, 99.26937366, 99.52599212, 97.66948095,
#        99.44354051, 99.2060097 , 99.68665486, 98.20053732, 98.86377199,
#        98.69417335, 98.94546263, 98.86372665, 99.23817788, 99.33233584,
#        98.85261413, 98.25512459, 99.2913459 , 99.06762748, 99.15186851,
#        98.8762207 , 98.59967213, 99.36434989, 98.56988944, 98.60872203,
#        98.78005243, 98.63766637, 98.9697716 , 98.15730207, 99.100819  ,
#        98.29504131, 98.41511265, 97.82482963, 98.87926065, 98.8999155 ,
#        99.09505192, 95.11508968, 97.72706653, 98.70903331, 98.43924393,
#        98.47249998, 98.49646685, 98.4190637 , 98.25810882, 98.04884523,
#        98.95371271, 97.47957138, 96.77479602, 96.95186175, 98.80856053,
# ...

# %%
# Create a DataFrame
df = pd.DataFrame({'time': monthly_dates, 
                   'wind_vorticity': monthly_vorts, 
                   'wind_shear': monthly_shear, 
                   'wind_stretch': monthly_stretch, 
                  'wind_north': monthly_vs, 
                  'wind_east': monthly_us, 
                  'sic': matchings_sics})

# Create a new row for units
# units_row = pd.DataFrame({'time': ['datetime'], 
#                           'wind_vorticity': ['s-1'],
#                           'wind_north': ['m s-1'],
#                           'wind_east': ['m s-1'],
#                          }, index=['unit'])

# Concatenate the units row with the original DataFrame
# df = pd.concat([units_row,df])

print(df)

# Save the DataFrame to a CSV file
df.to_csv('/Users/mackenziejewell/Desktop/BeaufortSeaSIC_Wind_ERA5_JFMA_2000-2022_v2.csv', index=False)
# Out:
#          time  wind_vorticity    wind_shear  wind_stretch  wind_north  \
# 0  2000-01-01        0.000004  1.025480e-07      0.000002   -0.962263
# 1  2000-02-01       -0.000003  3.963650e-06      0.000004   -1.314405
# 2  2000-03-01       -0.000007  2.281855e-06      0.000006   -2.659988
# 3  2000-04-01       -0.000001 -8.849868e-07      0.000003   -1.544069
# 4  2001-01-01       -0.000004  5.001343e-06      0.000005   -1.936381
# ..        ...             ...           ...           ...         ...
# 87 2021-04-01       -0.000002  1.139868e-06     -0.000004    1.163331
# 88 2022-01-01        0.000002 -1.329986e-07      0.000002   -1.504936
# 89 2022-02-01       -0.000001  1.183941e-07      0.000004   -0.653507
# 90 2022-03-01       -0.000004  3.403173e-06      0.000004   -0.814912
# 91 2022-04-01       -0.000004  2.218669e-07      0.000003   -0.922832
#
#     wind_east        sic
# 0    0.638218        NaN
# 1   -0.507859        NaN
# 2   -3.084038        NaN
# ...

# %%
df = pd.read_csv('/Users/mackenziejewell/Desktop/BeaufortSeaWind_ERA5_JFMA_2000-2022.csv')
df
# Out:
#                    time           wind_vorticity           wind_north  \
# 0              datetime                      s-1                m s-1
# 1   2000-01-01 00:00:00    3.894194259770387e-06  -0.9622625179829136
# 2   2000-02-01 00:00:00  -3.4261960917428367e-06  -1.3144052198954992
# 3   2000-03-01 00:00:00   -6.507820521687133e-06   -2.659987992096332
# 4   2000-04-01 00:00:00  -1.4086752047410151e-06  -1.5440691156157602
# ..                  ...                      ...                  ...
# 88  2021-04-01 00:00:00  -1.8815063773520367e-06   1.1633306303682427
# 89  2022-01-01 00:00:00    1.695547926352261e-06   -1.504935689796243
# 90  2022-02-01 00:00:00   -1.254708274172354e-06  -0.6535072805626052
# 91  2022-03-01 00:00:00   -4.282908851998407e-06  -0.8149118418655088
# 92  2022-04-01 00:00:00  -3.5544928986852754e-06  -0.9228319138288498
#
#               wind_east
# 0                 m s-1
# 1      0.63821817549967
# 2   -0.5078591986426285
# 3   -3.0840379057391996
# ...

# %% [markdown]
# ### Save to netcdf

# %%
# ds_atm =xr.Dataset(
#             data_vars=dict(
#                 u=(["year", "doy"], all_u, {"units": "m/s", "long_name":"average eastward"}),
#                 v=(["year", "doy"], all_v, {"units": "m/s", "long_name":"average northward"}),
#                 speed=(["year", "doy"], all_s, {"units": "m/s", "long_name":"average speed"}),
#                 msl = (["year", "doy"], all_m, {"units": "hPa", "long_name":"average msl"}), 

#             ),
#             coords=dict(
#                 year =(["year"], years),
#                 doy=(["doy"], np.arange(1,366), {"units": "day", "long_name":"julian from Jan 1 (doy=1)"}),
#                # time=date_list,
#             ),
#             attrs=dict(description="ERA5 winds and msl averages in MASIE-defined Beaufort Sea by year (only north of 70N)"),
#         )

# ds_atm.to_netcdf(path='/Users/mackenziejewell/Desktop/BeaufortAtmos.nc', mode='w', format="NETCDF4")

# %%
ds_atm.sel(year=2013).u.plot()

# %% [markdown]
# ### Loop through all SIM data

# %%
all_u = np.array([])
all_v = np.array([])
all_s = np.array([])
all_nanfrac = np.array([])

years = np.arange(1978, 2023)

for year in years:

    [u, v] = grab_icedrift_range(start_date=datetime(year, 1, 1), 
                        end_date=datetime(year, 12, 31), 
                        PPD_drift_path='/Volumes/Jewell_EasyStore/NSIDC-0116_PPdrift/', 
                        PPD_filename='icemotion_daily_nh_25km_{}0101_{}1231_v4.1.nc', 
                        return_vars=['u', 'v'],lat_range=[0, 90], lon_range=[0, 360])
    # ice drift speed
    s = np.sqrt(u**2 + v**2)
    
    # find daily means
    avg_u = np.array([])
    avg_v = np.array([])
    avg_s = np.array([])
    nan_frac = np.array([])
    
    for tt in range(len(u)): 
        avg_u = np.append(avg_u, np.nanmean(u[tt][within_poly]))
        avg_v = np.append(avg_v, np.nanmean(v[tt][within_poly]))
        avg_s = np.append(avg_s, np.nanmean(s[tt][within_poly]))
        
        nans = np.sum(np.isnan(s[tt][within_poly]))
        total = len(s[tt][within_poly])
        nan_frac = np.append(nan_frac, nans/total)

    # save to master list
    all_u = np.append(all_u, avg_u[:365])
    all_v = np.append(all_v, avg_v[:365])
    all_s = np.append(all_s, avg_s[:365])
    all_nanfrac = np.append(all_nanfrac, nan_frac[:365])
    
    
all_u = np.reshape(all_u, (len(years), int(len(all_u)/len(years))))
all_v = np.reshape(all_v, (len(years), int(len(all_v)/len(years))))
all_s = np.reshape(all_s, (len(years), int(len(all_s)/len(years))))
all_nanfrac = np.reshape(all_nanfrac, (len(years), int(len(all_nanfrac)/len(years))))
# Out:
# /Users/mackenziejewell/Documents/GitHub/PrettyPolarPlots/../Libraries_functions/LIB_PPdrift_NSIDC0116.py:411: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'julian', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   ds['time'] = CFTime.to_datetimeindex()
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_90008/582593167.py:25: RuntimeWarning: Mean of empty slice
#   avg_u = np.append(avg_u, np.nanmean(u[tt][within_poly]))
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_90008/582593167.py:26: RuntimeWarning: Mean of empty slice
#   avg_v = np.append(avg_v, np.nanmean(v[tt][within_poly]))
# /var/folders/p8/hz449fpx6nscv0jb1klyfqb40000gp/T/ipykernel_90008/582593167.py:27: RuntimeWarning: Mean of empty slice
#   avg_s = np.append(avg_s, np.nanmean(s[tt][within_poly]))
# ...

# %% [markdown]
# ### Save to netcdf

# %%
ds_ice =xr.Dataset(
            data_vars=dict(
                u=(["year", "doy"], all_u, {"units": "cm/s", "long_name":"average eastward"}),
                v=(["year", "doy"], all_v, {"units": "cm/s", "long_name":"average northward"}),
                speed=(["year", "doy"], all_s, {"units": "cm/s", "long_name":"average speed"}),
                nan_frac = (["year", "doy"], all_nanfrac, {"units": " ", "long_name":"fraction of region that are nan"}), 

            ),
            coords=dict(
                year =(["year"], years),
                doy=(["doy"], np.arange(1,366), {"units": "day", "long_name":"julian from Jan 1 (doy=1)"}),
               # time=date_list,
            ),
            attrs=dict(description="Ice drift averages in MASIE-defined Beaufort Sea by year"),
        )

# ds_ice.to_netcdf(path='/Users/mackenziejewell/Desktop/BeaufortDrift.nc', mode='w', format="NETCDF4")

# %%
ds_ice.sel(year=2013).nan_frac.plot()
